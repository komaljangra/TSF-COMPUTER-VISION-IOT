# %% [markdown]
# ## **OBJECT DETECTION OPTICAL CHARACTER RECOGNITION(OCR)**

# %% [markdown]
# **AUTHOR:KOMAL JANGRA**

# %% [markdown]
# ##OBJECTIVE
#
# Implement an object detector which identifies the classes of the objects in an image or video

# %%
from keras.applications.resnet import ResNet50
from keras.applications import imagenet_utils
from keras.preprocessing.image import img_to_array,load_img
import numpy as np
import cv2 
from google.colab.patches import cv2_imshow
# !pip install Pillow
from PIL import Image
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)

# %% [markdown]
# LOAD THE IMAGE

# %%
img_path = '/content/cat&dog.jpg'
img = load_img(img_path)
disp_img = cv2.imread("/content/cat&dog.jpg")

# %%
cv2_imshow(disp_img)
# Out:
# <PIL.Image.Image image mode=RGB size=241x209 at 0x7FC73125EB50>

# %% [markdown]
# RESIZE THE IMAGE AND CONVERT IT INTO AN ARRAY

# %%
img = img.resize((224,224))
img_array = img_to_array(img)
#convert the image into 4D
img_array = np.expand_dims(img_array, axis=0)

# %% [markdown]
# PREPROCESS THE INPUT IMAGE ARRAY

# %%
img_array = imagenet_utils.preprocess_input(img_array)

# %% [markdown]
# THE MODEL

# %%
pretrained_model = ResNet50(weights='imagenet')

#predict using predict()
prediction = pretrained_model.predict(img_array)

#decode the prediction
actual_prediction = imagenet_utils.decode_predictions(prediction)

print("predicted object is")
print(actual_prediction[0][1])
print(actual_prediction[0][4])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102973440/102967424 [==============================] - 1s 0us/step
# 102981632/102967424 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
# 49152/35363 [=========================================] - 0s 0us/step
# predicted object is
# ('n02123045', 'tabby', 0.1286069)
# ('n02109047', 'Great_Dane', 0.03482046)
